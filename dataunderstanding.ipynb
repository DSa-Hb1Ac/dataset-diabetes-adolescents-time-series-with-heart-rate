# %%
import pandas as ps
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Fitbit Sleep understanding

# %%
# import data from data-csv\Fitbit\Fitbit-sleep.csv as dataframe
df = ps.read_csv('data-csv/Fitbit/Fitbit-sleep.csv')
df.head(10)
# Out:
#    Subject code number Local datetime start [ISO8601]  \
# 0                  903       2019-10-15T00:17:00+0200
# 1                  903       2019-10-15T00:20:30+0200
# 2                  903       2019-10-15T00:29:30+0200
# 3                  903       2019-10-15T00:45:00+0200
# 4                  903       2019-10-15T00:49:30+0200
# 5                  903       2019-10-15T01:11:30+0200
# 6                  903       2019-10-15T01:18:00+0200
# 7                  903       2019-10-15T01:20:00+0200
# 8                  903       2019-10-15T01:27:00+0200
# 9                  903       2019-10-15T01:42:00+0200
#
#   Local date start [yyyy-mm-dd] Local time start[hh:mm]  \
# 0                    2019-10-15                   00:17
# 1                    2019-10-15                   00:20
# 2                    2019-10-15                   00:29
# 3                    2019-10-15                   00:45
# 4                    2019-10-15                   00:49
# ...

# %%
df.describe()
# Out:
#        Subject code number  UTC offset start [hr]   duration [s]
# count        100709.000000          100709.000000  100709.000000
# mean            946.402308               1.139302     632.666693
# std              28.574757               0.346263    1013.353189
# min             903.000000               1.000000      30.000000
# 25%             918.000000               1.000000      60.000000
# 50%             943.000000               1.000000     180.000000
# 75%             973.000000               1.000000     810.000000
# max             995.000000               2.000000   25260.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100709 entries, 0 to 100708
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Subject code number             100709 non-null  int64
#  1   Local datetime start [ISO8601]  100709 non-null  object
#  2   Local date start [yyyy-mm-dd]   100709 non-null  object
#  3   Local time start[hh:mm]         100709 non-null  object
#  4   UTC offset start [hr]           100709 non-null  int64
#  5   level                           100709 non-null  object
#  6   duration [s]                    100709 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 5.4+ MB

# %%
# heatmap
sns.heatmap(data=df.corr(), annot=True)
plt.show()

# %% [markdown]
# # Fitbit-Heart-Rate Understanding

# %%
# import data from data-csv\Fitbit\Fitbit-heart-rate.csv as dataframe
df = ps.read_csv('data-csv/Fitbit/Fitbit-heart-rate.csv')
df.head(10)
# Out:
#    Subject code number  Local datetime [ISO8601] Local date [yyyy-mm-dd]  \
# 0                  903  2019-10-15T00:00:00+0200              2019-10-15
# 1                  903  2019-10-15T00:01:00+0200              2019-10-15
# 2                  903  2019-10-15T00:02:00+0200              2019-10-15
# 3                  903  2019-10-15T00:03:00+0200              2019-10-15
# 4                  903  2019-10-15T00:04:00+0200              2019-10-15
# 5                  903  2019-10-15T00:05:00+0200              2019-10-15
# 6                  903  2019-10-15T00:06:00+0200              2019-10-15
# 7                  903  2019-10-15T00:07:00+0200              2019-10-15
# 8                  903  2019-10-15T00:08:00+0200              2019-10-15
# 9                  903  2019-10-15T00:09:00+0200              2019-10-15
#
#   Local time [hh:mm]  UTC offset [hr]  heart rate [#/min]
# 0              00:00                2                  64
# ...

# %%
df.describe()
# Out:
#        Subject code number  UTC offset [hr]  heart rate [#/min]
# count         2.771807e+06     2.771807e+06        2.771807e+06
# mean          9.467871e+02     1.138273e+00        8.025617e+01
# std           2.868141e+01     3.451860e-01        1.857083e+01
# min           9.030000e+02     1.000000e+00        3.900000e+01
# 25%           9.180000e+02     1.000000e+00        6.700000e+01
# 50%           9.430000e+02     1.000000e+00        7.800000e+01
# 75%           9.730000e+02     1.000000e+00        9.200000e+01
# max           9.950000e+02     2.000000e+00        2.020000e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2771807 entries, 0 to 2771806
# Data columns (total 6 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Subject code number       int64
#  1   Local datetime [ISO8601]  object
#  2   Local date [yyyy-mm-dd]   object
#  3   Local time [hh:mm]        object
#  4   UTC offset [hr]           int64
#  5   heart rate [#/min]        int64
# dtypes: int64(3), object(3)
# memory usage: 126.9+ MB

# %% [markdown]
# # Fitbit-Steps Understanding

# %%
# import data from data-csv\Fitbit\Fitbit-steps.csv as dataframe
df = ps.read_csv('data-csv/Fitbit/Fitbit-steps.csv')
df.head(10)
# Out:
#    Subject code number  Local datetime [ISO8601] Local date [yyyy-mm-dd]  \
# 0                  903  2019-10-15T00:00:00+0200              2019-10-15
# 1                  903  2019-10-15T00:01:00+0200              2019-10-15
# 2                  903  2019-10-15T00:02:00+0200              2019-10-15
# 3                  903  2019-10-15T00:03:00+0200              2019-10-15
# 4                  903  2019-10-15T00:04:00+0200              2019-10-15
# 5                  903  2019-10-15T00:05:00+0200              2019-10-15
# 6                  903  2019-10-15T00:06:00+0200              2019-10-15
# 7                  903  2019-10-15T00:07:00+0200              2019-10-15
# 8                  903  2019-10-15T00:08:00+0200              2019-10-15
# 9                  903  2019-10-15T00:09:00+0200              2019-10-15
#
#   Local time [hh:mm]  UTC offset [hr]  steps [#]
# 0              00:00                2          0
# 1              00:01                2          0
# ...

# %%
df.describe()
# Out:
#        Subject code number  UTC offset [hr]     steps [#]
# count         3.041280e+06     3.041280e+06  3.041280e+06
# mean          9.471250e+02     1.137311e+00  7.451607e+00
# std           2.881741e+01     3.441750e-01  1.964943e+01
# min           9.030000e+02     1.000000e+00  0.000000e+00
# 25%           9.187500e+02     1.000000e+00  0.000000e+00
# 50%           9.435000e+02     1.000000e+00  0.000000e+00
# 75%           9.732500e+02     1.000000e+00  0.000000e+00
# max           9.950000e+02     2.000000e+00  1.800000e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3041280 entries, 0 to 3041279
# Data columns (total 6 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Subject code number       int64
#  1   Local datetime [ISO8601]  object
#  2   Local date [yyyy-mm-dd]   object
#  3   Local time [hh:mm]        object
#  4   UTC offset [hr]           int64
#  5   steps [#]                 int64
# dtypes: int64(3), object(3)
# memory usage: 139.2+ MB

# %% [markdown]
# # Abbott Understanding

# %%
# import data from data-csv\Abbott.csv as dataframe
df = ps.read_csv('data-csv/Abbott.csv')
df.head(10)
# Out:
# C:\Users\info\AppData\Local\Temp\ipykernel_8540\1623190051.py:2: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = ps.read_csv('data-csv/Abbott.csv')
#    Subject code number  Local datetime [ISO8601] Local date [yyyy-mm-dd]  \
# 0                  903  2019-10-15T00:14:00+0200              2019-10-15
# 1                  903  2019-10-15T00:29:00+0200              2019-10-15
# 2                  903  2019-10-15T00:44:00+0200              2019-10-15
# 3                  903  2019-10-15T00:59:00+0200              2019-10-15
# 4                  903  2019-10-15T01:14:00+0200              2019-10-15
# 5                  903  2019-10-15T01:29:00+0200              2019-10-15
# 6                  903  2019-10-15T01:44:00+0200              2019-10-15
# 7                  903  2019-10-15T01:59:00+0200              2019-10-15
# 8                  903  2019-10-15T02:14:00+0200              2019-10-15
# ...

# %%
df.describe()
# Out:
#        Subject code number  UTC offset [hr]   Record Type  \
# count         58577.000000     58536.000000  58577.000000
# mean            943.427642         1.164275      0.291121
# std              29.154267         0.370528      1.086347
# min             903.000000         1.000000      0.000000
# 25%             918.000000         1.000000      0.000000
# 50%             929.000000         1.000000      0.000000
# 75%             962.000000         1.000000      0.000000
# max             995.000000         2.000000      6.000000
#
#        Historic Glucose [mmol/l]  Scan Glucose [mmol/l]  \
# count               51039.000000            5627.000000
# mean                    9.445401               9.415052
# std                     3.865403               4.101428
# min                     2.200000               2.200000
# 25%                     6.400000               6.100000
# 50%                     8.900000               8.900000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58577 entries, 0 to 58576
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Subject code number               58577 non-null  int64
#  1   Local datetime [ISO8601]          58577 non-null  object
#  2   Local date [yyyy-mm-dd]           58577 non-null  object
#  3   Local time [hh:mm]                58577 non-null  object
#  4   UTC offset [hr]                   58536 non-null  float64
#  5   Record Type                       58577 non-null  int64
#  6   Historic Glucose [mmol/l]         51039 non-null  float64
#  7   Scan Glucose [mmol/l]             5627 non-null   float64
#  8   Non-numeric Rapid-Acting Insulin  1 non-null      float64
#  9   Rapid-Acting Insulin [IU]         0 non-null      float64
#  10  Non-numeric Food                  2 non-null      float64
# ...

# %% [markdown]
# # Medtronic Understanding

# %%
# import data from data-csv\Medtronic.csv as dataframe
df = ps.read_csv('data-csv/Medtronic.csv', on_bad_lines='skip')
df.head(10)
# Out:
# C:\Users\info\AppData\Local\Temp\ipykernel_8540\3676290082.py:2: DtypeWarning: Columns (7,11,12,13,16,17,19,20,21,35,37,40,42,44,45,46,47,48,49) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = ps.read_csv('data-csv/Medtronic.csv', on_bad_lines='skip')
#    Subject code number  Local datetime [ISO8601] Local date [yyyy-mm-dd]  \
# 0                  903  2020-01-10T21:22:01+0100              2020-01-10
# 1                  903  2020-01-10T21:21:58+0100              2020-01-10
# 2                  903  2020-01-10T21:21:57+0100              2020-01-10
# 3                  903  2020-01-10T21:21:57+0100              2020-01-10
# 4                  903  2020-01-10T21:21:57+0100              2020-01-10
# 5                  903  2020-01-10T21:00:00+0100              2020-01-10
# 6                  903  2020-01-10T19:52:17+0100              2020-01-10
# 7                  903  2020-01-10T19:52:11+0100              2020-01-10
# ...

# %%
df.describe()
# Out:
#        Subject code number  UTC offset [hr]           File          Index  \
# count        270210.000000    270210.000000  270210.000000  270210.000000
# mean            961.975797         1.132882       1.359102   13305.327634
# std              22.746004         0.339448       0.479738   10733.150580
# min             903.000000         1.000000       1.000000       0.000000
# 25%             944.000000         1.000000       1.000000    3689.000000
# 50%             974.000000         1.000000       1.000000   10730.000000
# 75%             976.000000         1.000000       2.000000   20958.000000
# max             995.000000         2.000000       2.000000   50910.000000
#
#        BG Reading [mmol/l]  Basal Rate [IU/hr]  Temp Basal Amount  \
# count         11784.000000        15460.000000         789.000000
# mean              9.952302            0.524499          64.714829
# std               4.368076            0.477086          74.818824
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270210 entries, 0 to 270209
# Data columns (total 50 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   Subject code number                  270210 non-null  int64
#  1   Local datetime [ISO8601]             270210 non-null  object
#  2   Local date [yyyy-mm-dd]              270210 non-null  object
#  3   Local time [hh:mm:ss]                270210 non-null  object
#  4   UTC offset [hr]                      270210 non-null  int64
#  5   File                                 270210 non-null  int64
#  6   Index                                270210 non-null  int64
#  7   New Device Time                      72 non-null      object
#  8   BG Reading [mmol/l]                  11784 non-null   float64
#  9   Basal Rate [IU/hr]                   15460 non-null   float64
#  10  Temp Basal Amount                    789 non-null     float64
# ...

# %% [markdown]
# # Population Understanding

# %%
# import data from data-csv\Population.csv as dataframe
df = ps.read_csv('data-csv/Population.csv')
df.head(10)
# Out:
#    Subject code number Gender [M=male F=female]  Length [cm]  Weight [kg]  \
# 0                  903                        F        154.5         42.7
# 1                  907                        F        168.2         58.7
# 2                  911                        F        172.0         59.8
# 3                  912                        M        162.0         74.4
# 4                  914                        M        186.6         68.5
# 5                  918                        M        150.2         41.1
# 6                  919                        M        175.5         71.2
# 7                  926                        F        174.2         60.5
# 8                  929                        F        172.0         81.3
# 9                  936                        M        167.0         61.4
#
#    Age [yr]  HbA1C_1 [yyyy]  HbA1C_1 [mm]  HbA1C_1 [mmol/mol]  HbA1C_2 [yyyy]  \
# ...

# %%
df.describe()
# Out:
#        Subject code number  Length [cm]  Weight [kg]   Age [yr]  \
# count            24.000000    24.000000    24.000000  24.000000
# mean            947.125000   168.604167    58.300000  13.541667
# std              29.437203    13.529564    14.591749   2.620640
# min             903.000000   150.200000    36.500000  10.000000
# 25%             918.750000   154.575000    42.775000  11.000000
# 50%             943.500000   169.200000    60.150000  14.000000
# 75%             973.250000   180.250000    71.125000  16.000000
# max             995.000000   190.400000    83.600000  17.000000
#
#        HbA1C_1 [yyyy]  HbA1C_1 [mm]  HbA1C_1 [mmol/mol]  HbA1C_2 [yyyy]  \
# count            24.0     24.000000           24.000000       17.000000
# mean           2019.0      8.916667           54.208333     2019.470588
# std               0.0      1.767254            7.483194        0.514496
# min            2019.0      6.000000           35.000000     2019.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Subject code number       24 non-null     int64
#  1   Gender [M=male F=female]  24 non-null     object
#  2   Length [cm]               24 non-null     float64
#  3   Weight [kg]               24 non-null     float64
#  4   Age [yr]                  24 non-null     int64
#  5   HbA1C_1 [yyyy]            24 non-null     int64
#  6   HbA1C_1 [mm]              24 non-null     int64
#  7   HbA1C_1 [mmol/mol]        24 non-null     int64
#  8   HbA1C_2 [yyyy]            17 non-null     float64
#  9   HbA1C_2 [mm]              17 non-null     float64
#  10  HbA1C_2 [mmol/mol]        16 non-null     float64
#  11  Pump brand                24 non-null     object
#  12  Pump model                22 non-null     object
# ...
