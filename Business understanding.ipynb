# %% [markdown]
# # Business understanding Isala opdracht
#
#
# ## Business doelen bepalen
# Inzicht te creëren in de onnauwkeurigheden van de HbA1C waardes.
#
#
# De volgende vragen zullen het hoofddoel ondersteunen:
#
# - Wanneer kan je zeggen dat er een significant verschil is waarop een arts of een verpleegkundige zou moeten reageren d.m.v. een visualisatie?
# - Hoe kunnen we diabetesverpleegkundigen inzicht geven in de foutmarge van HbA1c metingen op basis van een methode en of ze op basis van een verschil met een eerdere meting de behandeling moeten bijsturen?
# - CAP en EurA1c surveys overzichtelijker presenteren (ook over de Jaren heen én per methode).
# - Meer inzicht in welke methodes gemiddeld het beste zijn (meest betrouwbaar/ meest stabiel).
# - Hoe verandert een methode over de jaren heen?
# - Welke methodes blijven zich continue verbeteren?
# - Welke methodes wijken steeds meer af?
#
#
#
# ## Achtergrond
# Het Isala ziekenhuis en het lectoraat ICT-innovaties in de Zorg willen toewerken naar het verbeteren van de procedure rondom het bepalen van het juiste behandelplan voor een patiënt. Beter inzicht in de HbA1c waardes en de implicaties hiervan voor zorgverleners kan hierbij helpen. Isala en het lectoraat zijn dan ook op zoek naar manieren om de onnauwkeurigheden van de meetwaarden, en of er nu wel of juist niet een behandelplan moet worden bijgesteld, inzichtelijker en begrijpelijk te maken.
#
#
#
# ## Business doelen
#
# De onnauwkeurigheden (afwijkingen) van HbA1c metingen inzichtelijker en begrijpelijker te maken.
#
# Inzichtelijker en begrijpelijker maken of er nu wel of juist niet een behandelplan op moet worden gesteld op basis van HbA1c waarden.
#
#
#
# ## Business succes criteria
#
#
#
# # Situatie
#
#
# ## Overzicht van hulpbronnen
#
#
#
# ## Vereisten, veronderstellingen en beperkingen
#
#
#
# ## Risico’s en onvoorziene omstandigheden
#
#
#
# ## Terminologie
#
# ### Hoe werkt een HbA1c meting?
#
# Het HbA1c-gehalte kan op 2 manieren worden gemeten. Het HbA1c kan worden bepaald via meting in het bloed. U wordt hiervoor door de laborante in de ader van de arm geprikt. De uitslag duurt enkele dagen.
#
#
#
# Het HbA1c kan tegenwoordig ook door middel van een vingerprik worden bepaald met behulp van een 'point-of-care-testing device'. Voordeel hiervan is dat de uitslag binnen 5 minuten bekend is. (Ziekenhuis Gelderse Vallei, sd)
#
#
#
# ### Wat is HbA1c?
#
# Wat wordt er gemeten met het HbA1c? Hb is een afkorting van hemoglobine. Dat is de kleurstof in rode bloedcellen, die zorgt voor vervoer van zuurstof. Rode bloedcellen komen tijdens hun verblijf in het bloed glucose tegen. Hoe hoger de bloedglucose, hoe meer daarvan aan hemoglobine plakt.
#
#
#
# Rode bloedcellen hebben een levensduur van 2-3 maanden. Het HbA1c (of glyHb) geeft het percentage rode cellen aan waaraan glucose is geplakt, en weerspiegelt dus het gemiddelde glucosegehalte in de voorafgaande 2-3 maanden. Bij mensen zonder diabetes is het HbA1c 20-42 millimol per mol. Dat is de normaalwaarde uitgedrukt in millimol per mol sinds 2010.
#
#
#
# De bloedglucose wordt uitgedrukt in mmol/l, en het HbA1c in mmol/mol. Hoewel er een duidelijk verband bestaat tussen het HbA1c en de gemiddelde glucosewaarden, kan men de uitslagen dus niet rechtstreeks met elkaar vergelijken. (diep, sd)
#
#
#
# ### Wat zijn de streefwaarden van HbA1C?
#
# Algemene streefwaarden zijn uitkomsten, waarvan in onderzoek bij grote aantallen mensen met diabetes is bewezen dat ze de kans op complicaties uitstellen, beperken of voorkomen.
#
#
#
#
#
# (diep, sd)
#
#
#
# ### Wat is de RCV(Reference Change values) ?
#
# RCV = 2^1/2 × Z × (CVA^2 + CVI^2)^1/2
#
#
#
# Z = Het aantal standaard deviaties passend bij de kans. Wij gebruiken als kans 955, dit sluit aan op een standaarddeviatie van 1.95.
#
# CVA = De foutmarge van de verschillende methodes(CV%), deze data is te vinden in het CAP onderzoek en het EurA1c onderzoek.
#
# CVI = Biological variation, de biological variation is erg verschillend, dingen zoals wat je eet op een dag, hoelang je geslapen hebt, hoeveel je sport etc. heeft hier allemaal invloed op. Voor dit project zullen we 1.3% gebruiken, dit is een schatting gemaakt door Erna Lenters-Westra in een vorig onderzoek. (Lenters-Westra E, 2014)
#
#
#
# ## Kosten en baten
#
#
#
# ## Bepaal het doel van data mining
#
# ## Data Mining Goals
#
# ## Succescriteria voor datamining

# %% [markdown]
# ### HbA1C
#
# Heeft leeftijd invloed op hbA1C?
#
# Heeft lengte invloed op hbA1C?
#
# Heeft gewicht invloed op hbA1C?
#
# Heeft geslacht invloed op hbA1C?
#
#
#
#
#
# ### Diabetes
#
# #### Wat is diabetes?
#
# Diabetes (suikerziekte) is een ziekte waarbij het lichaam de bloedsuiker niet meer in evenwicht kan houden. Dat komt doordat het lichaam te weinig van het hormoon insuline heeft. De meest voorkomende typen diabetes zijn diabetes type 1 en diabetes type 2. (Wat is diabetes, sd)
#
#
#
# #### Wat is het verschil tussen type 1 en type 2 diabetes?
#
# Het lichaam van mensen met diabetes type 1 maakt zelf veel te weinig insuline aan. Dat komt doordat het afweersysteem de cellen die insuline aanmaken vernielt. Daarom moet je met diabetes type 1 insuline inspuiten, of een insulinepomp dragen. Dit type komt veel minder vaak voor: 1 op de 10 diabetespatiënten hebben dit type.
#
#
#
# Bij diabetes type 2 heeft het lichaam te weinig insuline. Bovendien reageert het niet meer goed op insuline: dat heet ongevoeligheid voor insuline. Mensen met diabetes type 2 krijgen meestal voedings- en bewegingsadviezen, aangevuld met medicijnen. Soms moet iemand ook insuline spuiten. Diabetes type 2 komt het vaakst voor: 9 van de 10 mensen met diabetes hebben diabetes type 2. Overgewicht en weinig beweging, maar ook oudere leeftijd naast erfelijke aanleg vergroten de kans. Hoewel ook mensen zonder overgewicht diabetes type 2 kunnen krijgen. (Diabetesfonds, n.d.)
#
#
#
# #### Met welk type diabetes gaan wij werken?
#
# De aangeleverde dataset heeft alleen diabetes type 1. Aanname is dat wij ook alleen met dit type zullen werken.
#
#
#
# ### Afwijkingen
#
# #### Wanneer is er een afwijking?
#
# Een afwijking van een meting is er een die een andere waarde geeft dan de werkelijke waarde. Er is geen vastgesteld maximaal afwijkingspercentage voor de HbA1c metingen, maar uit onderzoek van Lenters bleek wel dat zes uit de acht handzame meetapparaten veel te onnauwkeurig waren. Zelfs een op de vijf uitgebreidere labonderzoeken was niet nauwkeurig genoeg.
#
# #### Hoe worden abnormaliteiten op dit moment herkend? Wat zijn de implicaties hiervan?
#
# #### Hoe kom je achter de bepaalde afwijking?
#
# #### Wanneer heeft een afwijking invloed op het behandelplan?
#
# Het resultaat van een onnauwkeurige meting is dat een patient ten onrechte een diabetes diagnose kan krijgen. Wanneer de patient eerder al wel correct is gediagnosticeerd kan deze alsnog een te hoge dosis medicijnen voorgeschreven krijgen.
#
#
#
# ### Insulinepomp
#
# #### Wat is de werking van een insulinepomp?
#
# Een insulinepomp is een apparaatje dat telkens een klein beetje insuline inbrengt. Dit kan zowel met infusieslang als zonder. Als het om een pomp met infusieslang gaat wordt deze met een kort plastic naaldje onder de huik van de buik aangebracht. Deze ingebrachte insuline is kort werkend.
#
#
#
# #### Wat voor merken?
#
# #### Zijn er veel verschillen tussen de merken?
#
#
#
# ### Behandelplan
#
# #### Wat is het behandelplan voor type 1?
#
# De behandeling van diabetes mellitus type 1 bestaat uit het toedienen van insuline via een insulinepen of - pomp. De hoeveelheid en soort insuline wordt hierbij afgestemd op uw eetpatroon, de hoeveelheid koolhydraten die u eet en uw levensstijl. (Behandeling diabetes mellitus type 1, sd)
#
#
#
# #### Wat is het behandelplan voor type 2?
#
# De basis van d (Flash Glucose Monitoring, 2020)e behandeling van diabetes mellitus 2 bestaat uit voedingsadviezen en het stimuleren van lichaamsbeweging. Zonder deze leefstijlveranderingen is een goede behandeling erg moeilijk, soms zelfs onmogelijk. In grote lijnen betekenen de adviezen dat u gezond en niet te veel moet eten en tenminste een half uur per dag matig intensieve lichamelijke inspanning moet verrichten (bijvoorbeeld fietsen of wandelen). Als een gezonde leefstijl onvoldoende blijkt te werken, zijn er medicijnen die kunnen helpen. (Behandeling diabetes mellitus type 2, sd)
#
#
#
# #### Hoe vaak wordt er gekeken naar de effectiviteit van een behandelplan?
#
#
#
# #### Hoe wordt er nu bepaald of een wijziging moet komen in het behandelplan?
#
# Dit is een probleem waar Erna over had verteld. Doordat de HbA1c waarden soms anders worden geïnterpreteerd, kan een arts of verpleegkundige te snel reageren op kleine veranderingen in de HbA1C waarde. Daarnaast is het niet altijd even duidelijk wat het onzekerheidsgebied per methode is.
#
#
#
# #### Wat wordt er gemeten?
#
# In de test wordt het percentage geglyceerd hemoglobine in bloed bepaald. Glycering is het gevolg van glucosebinding aan hemoglobine. Glucose dat in het bloed circuleert heeft de neiging zich spontaan te hechten aan hemoglobine, het zuurstoftransporteiwit in de rode bloedcellen. Is glucose eenmaal gebonden dan laat het niet meer los. Deze verbinding wordt hemoglobine A1c (HbA1c) genoemd. De mate van glucosebinding hangt af van de hoeveelheid glucose in het bloed. Als een diabetespatiënt de bloedsuikerspiegel niet goed onder controle heeft, is de bloedglucosewaarde gemiddeld hoog, waardoor ook de HbA1c waarde hoog is. HbA1c biedt een betrouwbaarder bloedglucosebeeld dan een glucosemeting, omdat het gehalte HbA1c niet wordt beïnvloed door actuele veranderingen in dieet of medicatie. De levensduur van rode bloedcellen (en dus ook van hemoglobine) is 2 tot 3 maanden waardoor de HbA1c-waarde een indruk geeft van de gemiddelde glucosewaarde over de laatste paar maanden. (NVKC, 2011)
#
#
#
# #### Hoe wordt de bloedglucosesuiker gemeten?
#
# Een buisje bloed wordt afgenomen uit een ader aan de binnenkant van de arm, meestal in de plooi van de elleboog. Om deze ader goed te kunnen zien en voelen wordt een stuwbandje strak om de bovenarm getrokken. In de ader wordt geprikt met een holle naald waardoor het bloed in het buisje wordt gezogen. De naald wordt maar één keer gebruikt en daarna vernietigd. (NVKC, 2011)
#
#
#
# #### Hoe vaak wordt er gemeten?
#
# De HbA1c test wordt gebruikt om te controleren of een diabetespatiënt zijn/haar glucosespiegel gedurende een langere periode (2-3 maanden) onder controle heeft. De HbA1c bepaling is een zeer nuttig hulpmiddel om te beoordelen of de behandeling die de patiënt krijgt om de bloedsuikerspiegel onder controle te houden goed werkt. In het algemeen is het voldoende om de HbA1c twee keer per jaar te meten. Soms is de frequentie hoger, bijvoorbeeld als bij iemand net diabetes is vastgesteld en het juiste behandelschema nog moet worden ingesteld. (NVKC, 2011)
#
#
#
# ### Meetinstrumenten
#
# #### Welke meetinstrumenten wordt er gebruikt in het Isala ziekenhuis?
#
# De HbA1c meetinstrument in het Isala ziekenhuis is door bloed af te nemen en het vervolgens naar het laboratorium te sturen.
#
#
#
# #### Welke meetinstrumenten worden er thuis het vaakst gebruikt?
#
#
#
# Het HbA1c kan tegenwoordig ook door middel van een vingerprik worden bepaald om vervolgens naar het laboratorium gestuurd te worden.
#
#
#
# #### Welke meetinstrumenten wordt er verkocht bij de apotheek?
#
# Bij de huisartenpraktijk is het mogelijk om de HbA1c te meten met behulp van een ‘point of care testing device’.
#
#
#
# #### Welke meetinstrumenten zijn gebruikt bij de dataset?
#
# Er wordt een flash glucose monitor gebruikt. In dit geval precies de ‘Abbott FreeStyle Libre (2)‘. (Flash Glucose Monitoring, 2020)
#
#
#
#
#
# ### Tijden
#
# #### Wat is de gemiddelde insuline inname in de nacht/ overdag?
#
# De meest gehanteerde schema's zijn de volgende.
#
# 1 keer per dag: vóór de nacht een (middel)langwerkende insuline.
#
# 2 keer per dag: een combinatie van een kort- en een middel langwerkende insuline, die u inspuit vóór het ontbijt en vóór het avondeten.
#
# 4 keer per dag: driemaal per dag vóór het eten een kortwerkende insuline en eenmaal vóór de nacht een (middel)langwerkende insuline. (Hoe gebruik ik dit medicijn (insuline), 2021)
#
#
#
# #### Worden bolussen ook meegenomen in de meting?
#
# Een glucose meting is een moment opname. Bij deze meting heeft bolussen daadwerkelijk een effect. Bij het meten van de HbA1C waarde wordt een gemiddelde van je glucosewaarde over ongeveer 2-3 maanden berekend. De HbA1C waarde wordt over het algemeen twee keer in het jaar gemeten. Hier heeft bolussen dus minder effect.
#
#
#
#
#
# ### Variatiecoefficiënt, CV (correlation of variation)
#
# #### Wat geeft de CV precies aan?
#
# De variatiecoëfficiënt is een maat voor de relatieve variabiliteit. Het is de verhouding tussen de standaardafwijking en het gemiddelde (gemiddelde). Hoe kleiner de variatiecoëfficiënt is, hoe minder de gegevens verspreid zijn vanuit het gemiddelde. (Data science team, 2020)
#
#
#
# Variatiecoëfficiënt = (Standaardafwijking/ Gemiddelde) * 100.
#
#
#
# #### Wat is een gewenste cv-waarde?
#
# Een gewenst CV-waarde is onder de 3%.
#
#
#
#
#
# ### Bias
#
# #### Wat betekent bias in de context van dit onderzoek?
#
#
#
# #### Hoe wordt bias weergegeven?
#
# Bias wordt in de Amerikaanse CAP data weergegeven als een getal tussen de –1 en 1, waar dit getal een absolute toe- of afname van het percentage is. De werkelijke hoogte van de bias loopt nooit zo ver uit en een bias van 0,34 was een hoge uitschieter in 2021.
#
# In de Europese EurA1c data is het genoteerd als toe- of afname van het de hoeveelheid mmol/mol
#
#
#
#
#
# ### Lyophilised hemolysate samples
#
# #### Wat is lyophilised hemolysate samples?
#
# Dit zijn bevroren samples waarvan het water weggehaald is. Door dit te doen, kan het bloed langer bewaard worden. Deze methode wordt vaak gebruikt bij het vervoeren van bloedsamples. (The chemistry of lyophilized blood products, 2018)
